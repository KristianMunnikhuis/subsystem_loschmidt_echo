# %%
import numpy as np
from numpy import cos, sin, exp, pi,sqrt
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot
from mpmath import pcfd
from tqdm import tqdm
import sys
sys.path.append("../../../src/")
import kblock_ising_model as kb
import kibble_zurek as kz
from time import time

# %%
#P_n correlations do not calculate connected correlator at all
def P_n_correlations(n,l,state, even = True):
    #Term 1 
    indices = [i for i in range(0,n)]
    #Term 2 
    indices +=[i for i in range(n+l-1,2*n+l-1)]
    terms = kb.all_combinations(indices)
   # print(terms)
     ###
    x_c = []
    for a in terms[1:]:
      
        a = np.array(a)
        x_c.append(tuple(a - a[0]))  # convert to tuple for hashing
    counter = kz.Counter(x_c)

    # Extract vecs and counts as separate arrays/lists
    vecs = list(counter.keys())
    counts = np.array(list(counter.values()))
    #
    dat = []
    for term in range(len(vecs)):
        indices = vecs[term]
        degen = counts[term]

        if len(indices)%2 == 1:
            if even ==True:
                dat.append(0)
            else:
                constant = len(k)//2
                indices = list(indices) + [x + constant for x in indices]
                dat.append(np.sqrt(kz.sigma_general(indices,state))*degen)
        else:
            dat.append(kz.sigma_general(indices,state)*degen)
    dat.append(1)
    #All terms have equal weight. 

    return np.sum(dat)/2**(2*n)#,terms

# %%
#Simple Test
L = 100
n = 10
taus = np.logspace(-1,1,25)
Kibble_Zurek = []
Ground_State = []
Delta_values = []

for tau in taus:
    t= tau
    state_t = kz.state(L,tau,t)
    k0 = kb.k_vals(L)
    #U0 needs -g because of different conventions
    U0 = kb.U(k0,-kz.g(t,tau))

    P_kz = kz.P_n(n,state_t)
    P0 = kb.P_n(n,U0,k0)
    diff = kz.delta(state_t,[U0,k0],n)

    Kibble_Zurek+= [P_kz]
    Ground_State += [P0]
    Delta_values += [diff]
plot(taus,Kibble_Zurek,label="Time evolved to g=0")
plot(taus,Ground_State,label="Ground State value at g=0")
plot(taus,Delta_values,label="abs(Diff)")
plt.xlabel(r"$\tau$")
plt.legend()
plt.yscale("log")
plt.xscale("log")

# %%
#Simple Test
L = 200
n = 1
ns = np.arange(1,8)
taus = np.logspace(-1,0.5,50)
Data_array = np.zeros([len(ns),len(taus)])

Delta_values = []

for tau_i, tau in enumerate(taus):
    t = np.linspace(-3*tau,tau,100)
    delta_t = np.zeros([len(ns),len(t)])
    for t_i,ti in (enumerate(tqdm(t))):
        state_t = kz.state(L,tau,ti)
        k0 = kb.k_vals(L)
        #U0 needs -g because of different conventions
        U0 = kb.U(k0,-kz.g(ti,tau))

        P_kz = kz.P_n(n,state_t)
        P0 = kb.P_n(n,U0,k0)
        for n_i,n in enumerate(ns):
            diff = kz.delta(state_t,[U0,k0],n)

            delta_t[n_i,t_i]= diff

    delta_t=delta_t.mean(axis=1)
    for n_i in range(len(ns)):
        Data_array[n_i,tau_i] = delta_t[n_i]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]/Users/kristianmunnikhuis/Research Projects/subsystem_loschmidt_echo/scripts/Kibble_Zurek_Scaling/Kibble_Zurek_Scaling_Figures/../../../src/kibble_zurek.py:142: ComplexWarning: Casting complex values to real discards the imaginary part
#   C[nx,ny] = D(Nd,state)
# /Users/kristianmunnikhuis/Research Projects/subsystem_loschmidt_echo/scripts/Kibble_Zurek_Scaling/Kibble_Zurek_Scaling_Figures/../../../src/kblock_ising_model.py:130: ComplexWarning: Casting complex values to real discards the imaginary part
#   C[nx,ny] = D(Nd,T,k)
# 100%|██████████| 100/100 [00:10<00:00,  9.85it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.89it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.81it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.82it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.76it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.71it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.66it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.65it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.60it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.58it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.45it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.44it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.49it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.47it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.47it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.43it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.37it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.43it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.39it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.40it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.38it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.37it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.34it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.33it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.25it/s]
#  56%|█████▌    | 56/100 [00:06<00:04,  8.95it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 14
#      12 delta_t = np.zeros([len(ns),len(t)])
#      13 for t_i,ti in (enumerate(tqdm(t))):
# ---> 14     state_t = kz.state(L,tau,ti)
#      15     k0 = kb.k_vals(L)
#      16     #U0 needs -g because of different conventions
#
# File ~/Research Projects/subsystem_loschmidt_echo/scripts/Kibble_Zurek_Scaling/Kibble_Zurek_Scaling_Figures/../../../src/kibble_zurek.py:74, in state(L, tau, t)
#      72 #Generate momentum values
#      73 k = k_vals(L)
# ---> 74 us = np.array([u_tilde(tau,q,t) for q in k])
#      75 vs = np.array([v_tilde(tau,q,t) for q in k])
#      76 return [us,vs,k]
#
# File ~/Research Projects/subsystem_loschmidt_echo/scripts/Kibble_Zurek_Scaling/Kibble_Zurek_Scaling_Figures/../../../src/kibble_zurek.py:74, in <listcomp>(.0)
#      72 #Generate momentum values
#      73 k = k_vals(L)
# ---> 74 us = np.array([u_tilde(tau,q,t) for q in k])
#      75 vs = np.array([v_tilde(tau,q,t) for q in k])
#      76 return [us,vs,k]
#
# File ~/Research Projects/subsystem_loschmidt_echo/scripts/Kibble_Zurek_Scaling/Kibble_Zurek_Scaling_Figures/../../../src/kibble_zurek.py:26, in u_tilde(tau, q, tf)
#      24 nu = 1j*b*b*tau-1
#      25 #Can be unstable at large tau
# ---> 26 return prefactor*complex(pcfd(nu,argument))
#
# File ~/miniconda3/envs/TFIM/lib/python3.11/site-packages/mpmath/functions/orthogonal.py:118, in pcfd(ctx, n, z, **kwargs)
#      64 @defun
#      65 def pcfd(ctx, n, z, **kwargs):
#      66     r"""
#      67     Gives the parabolic cylinder function in Whittaker's notation
#      68     `D_n(z) = U(-n-1/2, z)` (see :func:`~mpmath.pcfu`).
#    (...)    116
#     117     """
# --> 118     return ctx.hypercomb(lambda: _hermite_param(ctx, n, z, 1), [], **kwargs)
#
# File ~/miniconda3/envs/TFIM/lib/python3.11/site-packages/mpmath/functions/hypergeometric.py:125, in hypercomb(ctx, function, params, discard_known_zeros, **kwargs)
#     120     print("    z", ctx.nstr(z))
#     121 #v = ctx.hyper(a_s, b_s, z, **kwargs)
#     122 #for a in alpha_s: v *= ctx.gamma(a)
#     123 #for b in beta_s: v *= ctx.rgamma(b)
#     124 #for w, c in zip(w_s, c_s): v *= ctx.power(w, c)
# --> 125 v = ctx.fprod([ctx.hyper(a_s, b_s, z, **kwargs)] + \
#     126     [ctx.gamma(a) for a in alpha_s] + \
#     127     [ctx.rgamma(b) for b in beta_s] + \
#     128     [ctx.power(w,c) for (w,c) in zip(w_s,c_s)])
#     129 if verbose:
#     130     print("    Value:", v)
#
# File ~/miniconda3/envs/TFIM/lib/python3.11/site-packages/mpmath/functions/hypergeometric.py:229, in hyper(ctx, a_s, b_s, z, **kwargs)
#     227     elif q == 2: return ctx._hyp2f2(a_s, b_s, z, **kwargs)
#     228     elif q == 3: return ctx._hyp2f3(a_s, b_s, z, **kwargs)
# --> 229     elif q == 0: return ctx._hyp2f0(a_s, b_s, z, **kwargs)
#     230 elif p == q+1:
#     231     return ctx._hypq1fq(p, q, a_s, b_s, z, **kwargs)
#
# File ~/miniconda3/envs/TFIM/lib/python3.11/site-packages/mpmath/functions/hypergeometric.py:996, in _hyp2f0(ctx, a_s, b_s, z, **kwargs)
#     994     T2 = ([-ctx.pi,w,rz],[1,-1,1+a-b],[],[a,2-b],[a-b+1],[2-b],rz)
#     995     return T1, T2
# --> 996 return ctx.hypercomb(h, [a, 1+a-b], **kwargs)
#
# File ~/miniconda3/envs/TFIM/lib/python3.11/site-packages/mpmath/functions/hypergeometric.py:127, in hypercomb(ctx, function, params, discard_known_zeros, **kwargs)
#     120     print("    z", ctx.nstr(z))
#     121 #v = ctx.hyper(a_s, b_s, z, **kwargs)
#     122 #for a in alpha_s: v *= ctx.gamma(a)
#     123 #for b in beta_s: v *= ctx.rgamma(b)
#     124 #for w, c in zip(w_s, c_s): v *= ctx.power(w, c)
#     125 v = ctx.fprod([ctx.hyper(a_s, b_s, z, **kwargs)] + \
#     126     [ctx.gamma(a) for a in alpha_s] + \
# --> 127     [ctx.rgamma(b) for b in beta_s] + \
#     128     [ctx.power(w,c) for (w,c) in zip(w_s,c_s)])
#     129 if verbose:
#     130     print("    Value:", v)
#
# File ~/miniconda3/envs/TFIM/lib/python3.11/site-packages/mpmath/functions/hypergeometric.py:127, in <listcomp>(.0)
#     120     print("    z", ctx.nstr(z))
#     121 #v = ctx.hyper(a_s, b_s, z, **kwargs)
#     122 #for a in alpha_s: v *= ctx.gamma(a)
#     123 #for b in beta_s: v *= ctx.rgamma(b)
#     124 #for w, c in zip(w_s, c_s): v *= ctx.power(w, c)
#     125 v = ctx.fprod([ctx.hyper(a_s, b_s, z, **kwargs)] + \
#     126     [ctx.gamma(a) for a in alpha_s] + \
# --> 127     [ctx.rgamma(b) for b in beta_s] + \
#     128     [ctx.power(w,c) for (w,c) in zip(w_s,c_s)])
#     129 if verbose:
#     130     print("    Value:", v)
#
# File ~/miniconda3/envs/TFIM/lib/python3.11/site-packages/mpmath/ctx_mp_python.py:1007, in PythonMPContext._wrap_libmp_function.<locals>.f(x, **kwargs)
#    1005         return ctx.make_mpc(mpc_f((x._mpf_, fzero), prec, rounding))
#    1006 elif hasattr(x, '_mpc_'):
# -> 1007     return ctx.make_mpc(mpc_f(x._mpc_, prec, rounding))
#    1008 raise NotImplementedError("%s of a %s" % (name, type(x)))
#
# File ~/miniconda3/envs/TFIM/lib/python3.11/site-packages/mpmath/libmp/gammazeta.py:2145, in mpc_rgamma(x, prec, rnd)
#    2144 def mpc_rgamma(x, prec, rnd='d'):
# -> 2145     return mpc_gamma(x, prec, rnd, 2)
#
# File ~/miniconda3/envs/TFIM/lib/python3.11/site-packages/mpmath/libmp/gammazeta.py:2054, in mpc_gamma(z, prec, rnd, type)
#    2052 lre, lim = mpc_log(z, wp)
#    2053 lre = to_fixed(lre, wp)
# -> 2054 lim = to_fixed(lim, wp)
#    2055 yre = ((lre*afix - lim*bfix)>>wp) - (lre>>1) + yre
#    2056 yim = ((lre*bfix + lim*afix)>>wp) - (lim>>1) + yim
#
# File ~/miniconda3/envs/TFIM/lib/python3.11/site-packages/mpmath/libmp/libmpf.py:509, in to_fixed(s, prec)
#     506     else:
#     507         return man, 1<<(-exp)
# --> 509 def to_fixed(s, prec):
#     510     """Convert a raw mpf to a fixed-point big integer"""
#     511     sign, man, exp, bc = s
#
# KeyboardInterrupt:

# %%
plt.loglog(taus,Data_array[::2].T)
# Out:
# [<matplotlib.lines.Line2D at 0x310d1da90>,
#  <matplotlib.lines.Line2D at 0x310c95190>,
#  <matplotlib.lines.Line2D at 0x310e0f8d0>,
#  <matplotlib.lines.Line2D at 0x310e0fc50>,
#  <matplotlib.lines.Line2D at 0x310e0ff90>]

# %%
file_name= f"time_insensitive_prob_density_difference_nmax={ns[-1]}_mintau=-E2_maxtau=E2.npy"

folder = "Data/"

path = folder+file_name
print(path)
#np.save(path,Data_array)
# Out:
# Data/time_insensitive_prob_density_difference_nmax=10_mintau=-E2_maxtau=E2.npy

# %%
X= np.load(path)[1:]
labels = np.arange(2,len(X)+2)

# %%
for i in range(len(labels)):
    l = labels[i]
    dat = X[i]
    plot(taus*l,dat/l,label=labels[i])
#plt.xscale("log")
plt.yscale("log")
plt.legend()
plt.xlim(10e-2,100)
# Out:
# (0.1, 100.0)

# %%
# Out:
# array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02])

# %%
#Simple Test
L = 100
n = 1
#data_groundstate = np.zeros([len(taus_2dplots,len(t))])
N_t = 100

r = np.arange(1,20)
taus_2dplots= np.logspace(-2,2,5)
t_range = np.linspace(-3,3,N_t)
data = np.zeros([len(taus_2dplots),N_t,len(r)])

for tau_i, tau0 in enumerate(taus_2dplots):
    t = tau0*t_range

    for t_i,t0 in (enumerate(tqdm(t))):
        state_t = kz.state(L,tau0,t0)
        P = kz.P_n(n,state_t)
        for r_i, r0 in enumerate(r):
            PP = P_n_correlations(n,r0,state_t)
            x = PP
            data[tau_i,t_i,r_i] = x

folder_path = "Data/"
file_path = folder_path+f"n={n}_PP_correlator.npz"

np.savez(
    file_path,
    data=data,
    taus=taus_2dplots,
    t_range=t_range,
    r=r
)
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 19.15it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.13it/s]
# 100%|██████████| 100/100 [00:05<00:00, 17.56it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.02it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.32it/s]

# %%
#Simple Test
L = 100
n = 2
#data_groundstate = np.zeros([len(taus_2dplots,len(t))])
N_t = 100

r = np.arange(1,20)
taus_2dplots= np.logspace(-2,2,5)
t_range = np.linspace(-3,3,N_t)
data = np.zeros([len(taus_2dplots),N_t,len(r)])

for tau_i, tau0 in enumerate(taus_2dplots):
    t = tau0*t_range

    for t_i,t0 in (enumerate(tqdm(t))):
        state_t = kz.state(L,tau0,t0)
        P = kz.P_n(n,state_t)
        for r_i, r0 in enumerate(r):
            PP = P_n_correlations(n,r0,state_t)
            x = PP
            data[tau_i,t_i,r_i] = x

folder_path = "Data/"
file_path = folder_path+f"n={n}_PP_correlator.npz"

np.savez(
    file_path,
    data=data,
    taus=taus_2dplots,
    t_range=t_range,
    r=r
)
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.81it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.73it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.38it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.88it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.67it/s]

# %%
#Simple Test
L = 100
n = 4
#data_groundstate = np.zeros([len(taus_2dplots,len(t))])
N_t = 100

r = np.arange(1,20)
taus_2dplots= np.logspace(-2,2,5)
t_range = np.linspace(-3,3,N_t)
data = np.zeros([len(taus_2dplots),N_t,len(r)])

for tau_i, tau0 in enumerate(taus_2dplots):
    t = tau0*t_range

    for t_i,t0 in (enumerate(tqdm(t))):
        state_t = kz.state(L,tau0,t0)
        P = kz.P_n(n,state_t)
        for r_i, r0 in enumerate(r):
            PP = P_n_correlations(n,r0,state_t)
            x = PP
            data[tau_i,t_i,r_i] = x

folder_path = "Data/"
file_path = folder_path+f"n={n}_PP_correlator.npz"

np.savez(
    file_path,
    data=data,
    taus=taus_2dplots,
    t_range=t_range,
    r=r
)
# Out:
# 100%|██████████| 100/100 [02:28<00:00,  1.48s/it]
# 100%|██████████| 100/100 [02:28<00:00,  1.48s/it]
# 100%|██████████| 100/100 [02:26<00:00,  1.46s/it]
# 100%|██████████| 100/100 [02:25<00:00,  1.46s/it]
# 100%|██████████| 100/100 [02:25<00:00,  1.46s/it]

# %%
#Simple Test
L = 100
n = 6
#data_groundstate = np.zeros([len(taus_2dplots,len(t))])
N_t = 100

r = np.arange(1,20)
taus_2dplots= np.logspace(-2,2,5)
t_range = np.linspace(-3,3,N_t)
data = np.zeros([len(taus_2dplots),N_t,len(r)])

for tau_i, tau0 in enumerate(taus_2dplots):
    t = tau0*t_range

    for t_i,t0 in (enumerate(tqdm(t))):
        state_t = kz.state(L,tau0,t0)
        P = kz.P_n(n,state_t)
        for r_i, r0 in enumerate(r):
            PP = P_n_correlations(n,r0,state_t)
            x = PP
            data[tau_i,t_i,r_i] = x

folder_path = "Data/"
file_path = folder_path+f"n={n}_PP_correlator.npz"

np.savez(
    file_path,
    data=data,
    taus=taus_2dplots,
    t_range=t_range,
    r=r
)
# Out:
# 100%|██████████| 100/100 [2:28:32<00:00, 89.13s/it]
# 100%|██████████| 100/100 [51:41<00:00, 31.02s/it]
# 100%|██████████| 100/100 [1:11:05<00:00, 42.65s/it]
# 100%|██████████| 100/100 [9:21:29<00:00, 336.89s/it]
# 100%|██████████| 100/100 [1:00:07<00:00, 36.07s/it]

# %%
np.load("Data/n=1_PP_correlator.npz")["data"]
# Out:
# array([[[0.26826992, 0.25120473, 0.25002333, 0.24999079, 0.24999805,
#          0.24999975, 0.24999998, 0.25      , 0.25      ],
#         [0.26917016, 0.25120377, 0.2499974 , 0.24998461, 0.24999712,
#          0.24999965, 0.24999997, 0.25      , 0.25      ],
#         [0.27003494, 0.25115689, 0.24995755, 0.24997591, 0.24999591,
#          0.24999954, 0.24999997, 0.25      , 0.25      ],
#         [0.27082382, 0.25104444, 0.24989905, 0.24996409, 0.24999441,
#          0.24999944, 0.24999997, 0.25      , 0.25      ],
#         [0.27148331, 0.25084157, 0.24981647, 0.24994872, 0.24999274,
#          0.2499994 , 0.25      , 0.25000001, 0.25      ],
#         [0.27194443, 0.25051794, 0.24970425, 0.24992983, 0.2499912 ,
#          0.24999952, 0.25000007, 0.25000002, 0.25      ],
#         [0.27212055, 0.2500384 , 0.24955781, 0.24990844, 0.24999043,
#          0.24999995, 0.25000019, 0.25000004, 0.25      ],
#         [0.27190585, 0.24936496, 0.24937558, 0.24988735, 0.24999148,
#          0.25000087, 0.25000038, 0.25000006, 0.25      ],
#         [0.27117486, 0.24846101, 0.24916223, 0.24987199, 0.24999591,
#          0.25000247, 0.2500006 , 0.25000006, 0.25      ],
#         [0.26978407, 0.24729861, 0.24893293, 0.24987123, 0.25000549,
#          0.25000472, 0.25000075, 0.25000001, 0.24999998]],
#
#        [[0.27986631, 0.25491188, 0.25081656, 0.25012711, 0.25001726,
#          0.2500017 , 0.24999999, 0.24999993, 0.24999998],
#         [0.28465183, 0.25632749, 0.25111541, 0.25017114, 0.25001865,
#          0.24999965, 0.24999898, 0.24999959, 0.24999988],
#         [0.29068364, 0.25814632, 0.25145507, 0.2501866 , 0.24999825,
#          0.2499879 , 0.24999454, 0.24999822, 0.24999951],
#         [0.29810201, 0.26023067, 0.2516421 , 0.25004313, 0.24989251,
#          0.24994151, 0.24997854, 0.24999364, 0.24999844],
#         [0.30661736, 0.26187891, 0.25103091, 0.24934951, 0.24952358,
#          0.24979844, 0.24993585, 0.24998482, 0.24999813],
#         [0.31480755, 0.26105333, 0.24800372, 0.2472459 , 0.24859077,
#          0.24952085, 0.2499031 , 0.25000748, 0.25001809],
#         [0.31893484, 0.25349   , 0.23998004, 0.24306724, 0.24745231,
#          0.24965427, 0.25024494, 0.25021704, 0.2500922 ],
#         [0.31177442, 0.23395798, 0.22755759, 0.24068148, 0.24958506,
#          0.25180575, 0.251125  , 0.25024819, 0.24989539],
#         [0.28359476, 0.20523285, 0.2264602 , 0.25184916, 0.256055  ,
#          0.25174213, 0.24923585, 0.24932751, 0.24993453],
#         [0.22953601, 0.19314402, 0.26111337, 0.26347304, 0.24599861,
#          0.24696023, 0.25128367, 0.25065206, 0.24961732]],
#
#        [[0.28147346, 0.25590238, 0.25122536, 0.25026616, 0.25005923,
#          0.25001337, 0.25000304, 0.25000069, 0.25000016],
#         [0.28786659, 0.25850788, 0.25210948, 0.25054537, 0.2501439 ,
#          0.25003833, 0.25001024, 0.25000273, 0.25000072],
#         [0.29751067, 0.26326613, 0.25405581, 0.25128203, 0.25040968,
#          0.25013077, 0.25004136, 0.25001287, 0.25000392],
#         [0.31353745, 0.27310386, 0.25899591, 0.25353836, 0.25137085,
#          0.25051404, 0.25018304, 0.25006003, 0.25001694],
#         [0.34325211, 0.29571437, 0.27249231, 0.26041158, 0.25427164,
#          0.25134719, 0.25010124, 0.24967488, 0.24960916],
#         [0.39587553, 0.33950349, 0.29675523, 0.26598991, 0.24625473,
#          0.23569757, 0.23194053, 0.23260331, 0.23565872],
#         [0.43309122, 0.37101965, 0.32325287, 0.29055737, 0.2700946 ,
#          0.2583198 , 0.25215774, 0.2493351 , 0.24833716],
#         [0.41957196, 0.3683958 , 0.3253633 , 0.29543551, 0.27640629,
#          0.2648364 , 0.25805389, 0.25420636, 0.25209638],
#         [0.33668623, 0.31970941, 0.27863705, 0.26197985, 0.25173895,
#          0.24415182, 0.2436654 , 0.24302737, 0.24482399],
#         [0.29940088, 0.29037901, 0.25679457, 0.25290447, 0.25017852,
#          0.25001609, 0.24999812, 0.25000216, 0.25000224]],
#
#        [[0.28149979, 0.255922  , 0.25123536, 0.25027043, 0.25006087,
#          0.25001395, 0.25000324, 0.25000076, 0.25000018],
#         [0.2879361 , 0.25856886, 0.25214624, 0.25056397, 0.25015235,
#          0.25004191, 0.25001167, 0.25000328, 0.25000093],
#         [0.29774337, 0.26351124, 0.25423463, 0.25139154, 0.25046994,
#          0.25016154, 0.25005622, 0.25001974, 0.25000698],
#         [0.31464932, 0.27452275, 0.26026962, 0.25450188, 0.25202575,
#          0.25092689, 0.25042895, 0.25020012, 0.25009391],
#         [0.35197732, 0.30891459, 0.28706313, 0.27418885, 0.26608302,
#          0.26079606, 0.25727742, 0.25490844, 0.25330376],
#         [0.45512717, 0.4390831 , 0.42469372, 0.41030467, 0.39589073,
#          0.38164563, 0.36777673, 0.35446553, 0.34186014],
#         [0.48207349, 0.46417234, 0.44635941, 0.42871802, 0.41136018,
#          0.39441092, 0.37799758, 0.36224021, 0.34724383],
#         [0.45231114, 0.43693355, 0.41980831, 0.40503808, 0.38968977,
#          0.37519556, 0.36104094, 0.34763929, 0.33498576],
#         [0.34606153, 0.32473187, 0.28744706, 0.2921624 , 0.26716097,
#          0.27631944, 0.2571276 , 0.26645607, 0.25187834],
#         [0.31317827, 0.29791331, 0.26848351, 0.2765761 , 0.25972647,
#          0.26710968, 0.25549047, 0.26058504, 0.25275922]],
#
#        [[0.28150005, 0.2559222 , 0.25123546, 0.25027048, 0.25006089,
#          0.25001396, 0.25000324, 0.25000076, 0.25000018],
#         [0.28793681, 0.2585695 , 0.25214663, 0.25056417, 0.25015245,
#          0.25004195, 0.25001169, 0.25000329, 0.25000093],
#         [0.29774589, 0.26351398, 0.2542367 , 0.25139287, 0.2504707 ,
#          0.25016195, 0.25005643, 0.25001985, 0.25000703],
#         [0.31466432, 0.2745433 , 0.26028976, 0.25451873, 0.25203857,
#          0.25093603, 0.25043517, 0.2502042 , 0.2500965 ],
#         [0.35236657, 0.30957963, 0.2879273 , 0.27517708, 0.26712749,
#          0.26184073, 0.25827978, 0.25583918, 0.25414512],
#         [0.46392715, 0.45661846, 0.45157772, 0.44690554, 0.44229284,
#          0.43767924, 0.43305602, 0.42842591, 0.42379363],
#         [0.49458142, 0.48916303, 0.4837453 , 0.47832906, 0.47291544,
#          0.46750591, 0.46210225, 0.45670657, 0.45132132],
#         [0.46388691, 0.45751602, 0.4517523 , 0.44729306, 0.44237255,
#          0.43781915, 0.43306667, 0.42845479, 0.42376822],
#         [0.35208947, 0.3170008 , 0.29231485, 0.28596266, 0.27403133,
#          0.27430604, 0.26635275, 0.26888397, 0.26253796],
#         [0.31497077, 0.2844647 , 0.2654564 , 0.26691191, 0.25871397,
#          0.26390097, 0.25755766, 0.26311679, 0.25730655]]])

# %%
def corr_length(tau):
    return sqrt(2*tau)

taus = np.logspace(-2,0.5,100)
plot(taus,corr_length(taus))
#plt.xscale("log")

# %%
import numpy as np
import matplotlib.pyplot as plt

L = 100
taus = np.logspace(-1, 1, 25)
n_values = [2, 4, 6, 8, 10, 12]

# Initialize storage
KZ_data = {n: [] for n in n_values}
GS_data = {n: [] for n in n_values}
Delta_data = {n: [] for n in n_values}

for tau in taus:
    t = tau
    state_t = kz.state(L, tau, t)
    k0 = kb.k_vals(L)
    U0 = kb.U(k0, -kz.g(t, tau))

    for n in n_values:
        P_kz = kz.P_n(n, state_t)

        diff = kz.delta(state_t, [U0, k0], n)

        KZ_data[n].append(P_kz)
                
        if n == n_values[0]:        
            P0 = kb.P_n(n, U0, k0)

            GS_data[n].append(P0)
        Delta_data[n].append(diff)

plt.figure(figsize=(8, 6))
for n in n_values:
    plt.plot(taus, KZ_data[n], label=fr"$P_n(n={n})$ Time evolved")
    if n == n_values[0]:
        plt.plot(taus, GS_data[n], linestyle='--', label="Ground state", color="black")
    #plt.plot(taus, Delta_data[n], linestyle=':', label=fr"$\Delta(n={n})$")

# Convert dictionaries to arrays: shape = (len(n_values), len(taus))
KZ_array = np.array([KZ_data[n] for n in n_values])
GS_array = np.array([GS_data[n] for n in n_values])
Delta_array = np.array([Delta_data[n] for n in n_values])

# Save to disk if desired:
# np.save("KZ_array.npy", KZ_array)
# np.save("GS_array.npy", GS_array)
# np.save("Delta_array.npy", Delta_array)

# Access examples:
# KZ_array[i, j] = P_n(n_values[i]) at taus[j]
# GS_array[i, j] = same for ground state
# Delta_array[i, j] = same for delta

plt.xlabel(r"$\tau$")
plt.ylabel("Value")
plt.xscale("log")
plt.yscale("log")
plt.legend()
plt.title("Comparison across different $n$")
plt.tight_layout()
plt.show()

# %%
plot(Data_array.T)
plt.loglog()
# Out:
# []
